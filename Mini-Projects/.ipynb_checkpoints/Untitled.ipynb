# %%
## Calculater

def add(a,b):
    return a+b
def sub(c,d):
    return c-d
def mul(e,f):
    return e*f
def div(g,h):
    if h == 0:
        return 'Error! Divisible by Zero!!'
    else:
        return g/h
    
num1=float(input("Enter a first number"))
num2=float(input("Enter a second number"))

add(num1,num2)
print("Addition of a",num1 , num2,"is:",add(num1, num2))

sub(num1,num2)
print("subtraction of a",num1 , num2,"is:",sub(num1, num2))

mul(num1,num2)
print("Multiplication of a",num1 , num2,"is:",mul(num1, num2))

div(num1,num2)
print("Division of a",num1 , num2,"is:",div(num1, num2))
# Out:
# Enter a first number34
# Enter a second number56
# Addition of a 34.0 56.0 is: 90.0
# subtraction of a 34.0 56.0 is: -22.0
# Multiplication of a 34.0 56.0 is: 1904.0
# Division of a 34.0 56.0 is: 0.6071428571428571

# %%
## Bank Application

Name = ["Siya","Shubh", "Ruhi", "Mansi", "Rhythm", "Aaradhya", "Vivan"]
Pswd = "123@16&X"

total_amount = 0.0

cmd_name = input("Please! Enter Your Name:") 
if cmd_name in Name:
    cmd_pswd = input("Please! Enter Ypur Password:")
    if cmd_pswd == Pswd:
        while True:
            print("\n WelCome!! \n\n1: Deposite Amount \n2: Withdraw Amount \n3: Check Your Amount \n4: Change Password \n5: Inquriy \n6: Exit") 
            choice = input("Enter Your choice to procced (1/2/3/4/5): ")
            
            if choice == "1":
                deposite_amount = float(input("Enter Your Amount:"))
                if deposite_amount > 0:
                    total_amount += deposite_amount
                    print("Amount Added Successfully!") 
                else:
                    print("Wrong Amount Entered !")
                
            elif choice == "2":
                withdraw_amount = float(input("Enter Your Amount:"))
                if withdraw_amount <= total_amount:
                    total_amount -= withdraw_amount
                    print("Successful ! withdraw_amount is", withdraw_amount)
                else:
                    print("Insufficient funds!")
                
            elif choice == "3":
                print("Your Total Amount Is" , total_amount)

            elif choice == "4":
                new_pswd = input("Enter Your New Password:")
                Pswd = new_pswd

            elif choice == "5":
                print("For Inquiries, Contact to Your Manager")

            elif choice == "6":
                print("Thankyou For Visiting !!") 
                break

            else:
                print("Invalid choice!")
        
            
    else:
        print("Wrong password! Please try again.")
        
else:
    print("Name not registered. Please register first.")
# Out:
# Please! Enter Your Name:Siya
# Please! Enter Ypur Password:123@16&X
#
#  WelCome!!
#
# 1: Deposite Amount
# 2: Withdraw Amount
# 3: Check Your Amount
# 4: Change Password
# 5: Inquriy
# 6: Exit
# Enter Your choice to procced (1/2/3/4/5): 1
# Enter Your Amount:1680
# Amount Added Successfully!
#
#  WelCome!!
#
# 1: Deposite Amount
# 2: Withdraw Amount
# 3: Check Your Amount
# 4: Change Password
# 5: Inquriy
# 6: Exit
# Enter Your choice to procced (1/2/3/4/5): 4
# Enter Your New Password:12345
#
#  WelCome!!
#
# 1: Deposite Amount
# 2: Withdraw Amount
# 3: Check Your Amount
# 4: Change Password
# 5: Inquriy
# 6: Exit
# Enter Your choice to procced (1/2/3/4/5): 1
# Enter Your Amount:4908
# Amount Added Successfully!
#
#  WelCome!!
#
# 1: Deposite Amount
# 2: Withdraw Amount
# 3: Check Your Amount
# 4: Change Password
# 5: Inquriy
# 6: Exit
# Enter Your choice to procced (1/2/3/4/5): 3
# Your Total Amount Is 6588.0
#
#  WelCome!!
#
# 1: Deposite Amount
# 2: Withdraw Amount
# ...
